# %%
import pandas as pd
import numpy as np
import joblib
import tensorflow as tf
import ast
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Embedding, GRU, LSTM, Dense, Dropout, 
                                     Bidirectional, Conv1D, GlobalMaxPooling1D, 
                                     Flatten, Concatenate,MultiHeadAttention, LayerNormalization)
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics.pairwise import cosine_similarity
# Load and clean data
df = pd.read_csv("../all_data_cleaned.csv")
df.dropna(subset=["title", "supercategory_cleaned", "Bow", "weighted_rating_class_2"], inplace=True)
df = df.sample(n=100000, random_state=6).reset_index(drop=True)
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
# Process labels
def list_to_str(x):
    if isinstance(x, str):
        try:
            lst = ast.literal_eval(x)
            return ' '.join(sorted(set(lst))) if isinstance(lst, list) else str(lst)
        except:
            return str(x)
    return str(x)

df["super_str"] = df["supercategory_cleaned"].apply(list_to_str)

# Label encoding
le_label = LabelEncoder()
df["y_label"] = le_label.fit_transform(df["super_str"])

# %%
# Clean text
def clean_text(text):
    if isinstance(text, str):
        words = text.lower().strip().split()
        return ' '.join(sorted(set(words)))
    return ""

df["clean_text"] = df["Bow"].apply(clean_text)

# Tokenization
tokenizer = Tokenizer(num_words=3000, oov_token="<OOV>")
tokenizer.fit_on_texts(df["clean_text"])
seq = tokenizer.texts_to_sequences(df["clean_text"])
padded_seq = pad_sequences(seq, maxlen=40, padding="post")

# Numeric data
scaler = MinMaxScaler()
numeric_data = scaler.fit_transform(df[["weighted_rating_class_2"]].astype(float))

# Prepare targets
y = to_categorical(df["y_label"])
num_classes = y.shape[1]

# Remove classes with only one sample
class_counts = pd.Series(np.argmax(y, axis=1)).value_counts()
single_sample_classes = class_counts[class_counts == 1].index
mask = ~np.isin(np.argmax(y, axis=1), single_sample_classes)

X_text = padded_seq[mask]
X_num = numeric_data[mask]
y = y[mask]
num_classes = y.shape[1]

# Train-test split
X_train_text, X_test_text, X_train_num, X_test_num, y_train, y_test = train_test_split(
    X_text, X_num, y, test_size=0.3, random_state=42, stratify=np.argmax(y, axis=1)
)

# %%
def build_model(model_type="bigru"):
    input_text = Input(shape=(40,))
    x = Embedding(input_dim=3001, output_dim=300)(input_text)
    
    if model_type == "gru":
        x = GRU(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3)(x)
        x = GRU(128, dropout=0.3, recurrent_dropout=0.3)(x)
    elif model_type == "lstm":
        x = LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3)(x)
        x = LSTM(128, dropout=0.3, recurrent_dropout=0.3)(x)
    elif model_type == "bigru":
        x = Bidirectional(GRU(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))(x)
        x = GlobalMaxPooling1D()(x)
    elif model_type == "bilstm":
        x = Bidirectional(LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))(x)
        x = GlobalMaxPooling1D()(x)
    elif model_type == "cnn":
        x = Conv1D(128, 5, activation='relu')(x)
        x = Conv1D(128, 3, activation='relu')(x)
        x = GlobalMaxPooling1D()(x)
    elif model_type == "attention":
        x = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
        x = LayerNormalization()(x)
        x = GlobalMaxPooling1D()(x)
    else:
        raise ValueError("Invalid model type. Choose from: gru, lstm, bigru, bilstm, cnn, attention, capsule, tcn")

    input_num = Input(shape=(1,))
    y = Dense(64, activation='relu')(input_num)

    z = Concatenate()([x, y])
    z = Dropout(0.5)(z)
    z = Dense(256, activation='relu')(z)
    output = Dense(num_classes, activation='softmax')(z)

    model = Model(inputs=[input_text, input_num], outputs=output)
    model.compile(optimizer=Adam(0.00025), 
                 loss="categorical_crossentropy", 
                 metrics=["accuracy"])
    return model

# %%
def train(model_type="bigru"):
    model = build_model(model_type)
    
    history = model.fit(
        [X_train_text, X_train_num], y_train,
        validation_data=([X_test_text, X_test_num], y_test),
        epochs=5, 
        batch_size=32,
        callbacks=[EarlyStopping(patience=3, restore_best_weights=True)]
    )

    model.save(f"{model_type}_supercategory_model.keras")
    joblib.dump(tokenizer, "tokenizer.pkl")
    joblib.dump(le_label, "le_label.pkl")
    joblib.dump(scaler, "scaler.pkl")

    # Plot training history
    plt.figure(figsize=(12, 5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')  # Validation -> Test
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    
    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Test Accuracy')  # Validation -> Test
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

    y_pred = np.argmax(model.predict([X_test_text, X_test_num], verbose=0), axis=1)
    y_true = np.argmax(y_test, axis=1)
    
    print(classification_report(y_true, y_pred, 
                              target_names=le_label.classes_,
                              labels=np.arange(len(le_label.classes_)),
                              zero_division=0))
    print("F1 Score:", f1_score(y_true, y_pred, average="weighted"))
    print("Accuracy:", accuracy_score(y_true, y_pred))
    
    return history

# %%
def get_recommendations(user_text, rating_class, model_type="bigru", top_k=5):
    model = tf.keras.models.load_model(f"{model_type}_supercategory_model.keras")
    tokenizer = joblib.load("tokenizer.pkl")
    le_label = joblib.load("le_label.pkl")
    scaler = joblib.load("scaler.pkl")

    clean_input = ' '.join(sorted(set(user_text.lower().strip().split())))
    seq = tokenizer.texts_to_sequences([clean_input])
    padded = pad_sequences(seq, maxlen=40, padding="post")
    numeric_input = scaler.transform(np.array([[rating_class]]))

    pred_idx = np.argmax(model.predict([padded, numeric_input], verbose=0))
    pred_super = le_label.inverse_transform([pred_idx])[0]
    
    super_df = df[df["super_str"] == pred_super].copy()
    
    if len(super_df) == 0:
        return pred_super, None

    embed_model = Model(inputs=model.inputs, outputs=model.layers[-3].output)
    
    user_embedding = embed_model.predict([padded, numeric_input], verbose=0)
    
    seqs = tokenizer.texts_to_sequences(super_df["clean_text"])
    padded_seqs = pad_sequences(seqs, maxlen=40, padding="post")
    numeric_super = scaler.transform(super_df[["weighted_rating_class_2"]].values)
    prod_embeddings = embed_model.predict([padded_seqs, numeric_super], verbose=0)
    
    similarities = cosine_similarity(user_embedding, prod_embeddings)[0]
    super_df["similarity"] = similarities
    
    top_products = super_df.sort_values(by="similarity", ascending=False).head(top_k)
    
    return pred_super, top_products[["title", "price", "rating", "product_url", "similarity"]]

# %%
selected_model_type = "cnn"
train(selected_model_type)

sample_input = "Araç torpido üstü aksesuarı"
pred_super, results = get_recommendations(
        user_text=sample_input,
        rating_class=1,
        model_type=selected_model_type,
        top_k=5
    )

print("Predicted Supercategory:", pred_super)
if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# Epoch 1/5
# 2188/2188 [==============================] - 12s 5ms/step - loss: 1.8033 - accuracy: 0.6224 - val_loss: 0.5050 - val_accuracy: 0.8995
# Epoch 2/5
# 2188/2188 [==============================] - 10s 5ms/step - loss: 0.4475 - accuracy: 0.9023 - val_loss: 0.2278 - val_accuracy: 0.9558
# Epoch 3/5
# 2188/2188 [==============================] - 10s 5ms/step - loss: 0.2464 - accuracy: 0.9426 - val_loss: 0.1434 - val_accuracy: 0.9713
# Epoch 4/5
# 2188/2188 [==============================] - 11s 5ms/step - loss: 0.1698 - accuracy: 0.9590 - val_loss: 0.1059 - val_accuracy: 0.9795
# Epoch 5/5
# 2188/2188 [==============================] - 11s 5ms/step - loss: 0.1294 - accuracy: 0.9678 - val_loss: 0.0886 - val_accuracy: 0.9830
#                                  precision    recall  f1-score   support
#
#                          abajur       0.68      0.83      0.75        18
#             acma alt bebek bezi       0.00      0.00      0.00         0
#                        aksesuar       0.99      0.98      0.99       589
#          aksesuar arabasi bebek       0.89      0.94      0.92        18
#             aksesuar giyim spor       0.98      1.00      0.99        45
#                    aksesuar oto       1.00      1.00      1.00      1506
#         aksesuari arabasi bebek       0.83      1.00      0.91        15
#           aksesuari koltugu oto       0.91      1.00      0.95        29
#       aksesuari mama sandalyesi       0.91      0.91      0.91        22
#                     aksesuarlar       0.99      0.99      0.99       653
#            aksesuarlari aksiyon       0.83      0.71      0.77        14
#         aksesuarlari aydinlatma       0.75      0.83      0.79        18
#              aksesuarlari banyo       0.97      0.99      0.98       194
#       aksesuarlari cep telefonu       0.98      1.00      0.99       429
#                         aksiyon       1.00      0.14      0.25         7
#          aktivite bebek eglence       0.96      0.96      0.96        45
#         aktivite sisme urunleri       0.98      0.99      0.98        92
#              albumleri fotograf       0.89      1.00      0.94        17
#             aletleri elektrikli       0.99      0.98      0.98       134
#      aletleri elektrikli mutfak       0.99      0.99      0.99       368
#       aletleri gelistirme vucut       1.00      1.00      1.00        67
#                  aletleri muzik       0.98      0.99      0.99       558
#                            alez       1.00      1.00      1.00        17
#                altin gram kulce       0.00      0.00      0.00         7
#             altin havale hesaba       0.00      0.00      0.00         1
#                 altin hediyelik       0.00      0.00      0.00         0
#                    altin ziynet       1.00      0.83      0.91         6
#               altini cumhuriyet       0.00      0.00      0.00         0
#                        ampuller       0.96      1.00      0.98        43
#             ankastre beyaz esya       1.00      1.00      1.00       121
#             anne emzirme saglik       1.00      0.90      0.95        61
#                       antre hol       0.98      1.00      0.99       116
#                           aplik       0.67      0.84      0.74        19
#                      armaturler       0.95      0.95      0.95        20
#         askeri giyim malzemeler       1.00      1.00      1.00        20
#                           avize       0.64      0.43      0.51        21
#                        ayakkabi       1.00      0.97      0.98       235
#                  ayakkabi erkek       0.97      0.97      0.97       176
# %%
sample_input = "Iphone cep telefonu aksesuarı telefon tutacağı"
pred_super, results = get_recommendations(
        user_text=sample_input,
        rating_class=1,
        model_type=selected_model_type,
        top_k=5
    )

print("Predicted Supercategory:", pred_super)
if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Predicted Supercategory: aksesuarlari cep telefonu
# Top recommended products:
#                                                                              title   price  rating                                                                                                                     product_url  similarity
#      ['kampanya', 'estevia', 'karel', 'kablolu', 'ekranli', 'masaustu', 'telefon'] 5249.80     0.0           https://www.hepsiburada.com/kampanya-estevia-karel-tm-145-kablolu-ekranli-masaustu-telefon-4172-yeni-pm-HBC000096QFO4    0.974867
#                                                         ['samsung', 'note', 'neo']  141.90     5.0                                      https://www.hepsiburada.com/tiger-samsung-note-3-neo-n7500-eb-bn750bbc-pm-telbatmdc3279689    0.971079
#                                      ['iphone', 'plus', 'arka', 'isik', 'entegre']  195.54     0.0                   https://www.hepsiburada.com/iphone-5s5c6g6-plus-arka-isik-ic-entegre-01502-1903-crm1544-2125-pm-HBC00009A1RBV    0.966893
# ['one', 'pair', 'profesyonel', 'joystick', 'pubg', 'oyun', 'atesleyici', 'aparat']  234.47     0.0 https://www.hepsiburada.com/one-pair-profesyonel-joystick-pubg-oyun-atesleyici-aparat-2-adet-1903-ykd4015-1296-pm-HBC000099C985    0.966814
# ['one', 'pair', 'profesyonel', 'joystick', 'pubg', 'oyun', 'atesleyici', 'aparat']  238.10     0.0 https://www.hepsiburada.com/one-pair-profesyonel-joystick-pubg-oyun-atesleyici-aparat-2-adet-1903-jul4015-1296-pm-HBC00009BKT5G    0.966814

# %%
sample_input = "Bilgisayar"
pred_super, results = get_recommendations(
        user_text=sample_input,
        rating_class=1,
        model_type=selected_model_type,
        top_k=5
    )

print("Predicted Supercategory:", pred_super)
if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Predicted Supercategory: oyuncu ozel
# Top recommended products:
#                                                                                                         title    price  rating                                                                                                                                                                   product_url  similarity
# ['excalibur', 'intel', 'core', 'ram', 'ssd', 'nvidia', 'geforce', 'rtx', 'freedos', 'masaustu', 'bilgisayar'] 55999.00     0.0 https://www.hepsiburada.com/casper-excalibur-e75l-144f-dft0x-0sd-intel-core-i5-14400f-32gb-ram-1tb-ssd-nvidia-geforce-rtx-5060ti-freedos-masaustu-bilgisayar-pm-HBC000099OBEF    0.750603
# ['excalibur', 'intel', 'core', 'ram', 'ssd', 'nvidia', 'geforce', 'rtx', 'freedos', 'masaustu', 'bilgisayar'] 62599.00     0.0 https://www.hepsiburada.com/casper-excalibur-e65h-147f-eft0x-0rd-intel-core-i7-14700f-64gb-ram-1tb-ssd-nvidia-geforce-rtx-5060ti-freedos-masaustu-bilgisayar-pm-HBC000099NC64    0.750582
#                  ['ideapad', 'gaming', 'intel', 'core', 'ssd', 'freedos', 'ips', 'tasinabilir', 'bilgisayar'] 33999.00     4.5           https://www.hepsiburada.com/lenovo-ideapad-gaming-3-intel-core-i5-12450h-16gb-512gb-ssd-rtx3050-freedos-15-6-ips-tasinabilir-bilgisayar-82s9015vtx-pm-HBC00004MP2D0    0.750345
#                           ['excalibur', 'intel', 'core', 'ram', 'nvme', 'ssd', 'windows', 'gaming', 'laptop'] 51999.00     5.0          https://www.hepsiburada.com/casper-excalibur-g870-1270-dfa0a-b-intel-core-i7-12700h-32gb-ram-1tb-nvme-ssd-gen4-6gb-rtx4050-windows-11-gaming-laptop-pm-HBC00005UY0S4    0.748516
#                                     ['intel', 'core', 'ram', 'ssd', 'hdd', 'masaustu', 'ofis', 'bilgisayari']  5819.03     3.7                                              https://www.hepsiburada.com/turbox-tx372-intel-core-i3-530-4gb-ram-128gb-ssd-320gb-hdd-masaustu-ofis-bilgisayari-pm-HB0000099T8O    0.730054

# %%
sample_input = "Erkek alt giyim pantolon"
pred_super, results = get_recommendations(
        user_text=sample_input,
        rating_class=1,
        model_type=selected_model_type,
        top_k=5
    )

print("Predicted Supercategory:", pred_super)
if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Predicted Supercategory: giyim
# Top recommended products:
#                                                      title   price  rating                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              product_url  similarity
#               ['erkek', 'bagcikli', 'cizgili', 'pantolon']  576.00     0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        https://www.hepsiburada.com/erkek-beli-bagcikli-cizgili-pantolon-p-HBCV000097HHMK    0.991874
#             ['junya', 'erkek', 'basic', 'tisort', 'siyah']  539.99     4.7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       https://www.hepsiburada.com/lufian-junya-erkek-basic-tisort-siyah-p-HBCV00006AQ5VM    0.984270
#                       ['erkek', 'aqua', 'gomlek', 'basic']  719.95     4.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        https://www.hepsiburada.com/u-s-polo-assn-erkek-aqua-gomlek-basic-50306285-vr007-p-HBCV000086T9GO    0.983227
# ['nautica', 'erkek', 'turuncu', 'baskili', 'mayo', 'sort']  499.00     4.4 https://adservice.hepsiburada.com/event/api/v1/track?event=...&redirect=https%3A%2F%2Fwww.hepsiburada.com%2Fnautica-erkek-turuncu-baskili-mayo-sort-t35513t-62l-p-HBCV00005GKPSX%3Fmagaza%3DNautica&eventName=sp-click&platform=desktop    0.979953
#                                   ['erkek', 'bej', 'mont'] 3499.90     0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              https://www.hepsiburada.com/erkek-bej-mont-p-HBCV000097N7U1    0.979011
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
sample_input = "Kadın üst giyim t-shirt"
pred_super, results = get_recommendations(
        user_text=sample_input,
        rating_class=1,
        model_type=selected_model_type,
        top_k=5
    )

print("Predicted Supercategory:", pred_super)
if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Predicted Supercategory: giyim
# Top recommended products:
#                                                                          title  price  rating                                                                                                          product_url  similarity
# ['yeni', 'nesilozel', 'guvenlikkoruma', 'yelegi', 'satinalsivile', 'satilmaz'] 850.00     0.0 https://www.hepsiburada.com/aldatmaz-yeni-nesil-ozel-guvenlik-koruma-yelegi-satinal-sivile-satilmaz-p-HBCV00006E8BFN    0.952036
#                                 ['maya', 'modern', 'grafik', 'shirt', 'siyah'] 404.99     4.7                                 https://www.hepsiburada.com/lufian-maya-modern-grafik-t-shirt-siyah-p-HBCV00003Z98PP    0.951907
#                                                                   ['pantolon'] 949.99     5.0                                                          https://www.hepsiburada.com/mango-pantolon-p-HBCV00007SDPZZ    0.949331
#                           ['cizgili', 'ozel', 'uretim', 'orj', 'sort', 'sari'] 441.89     0.0                                       https://www.hepsiburada.com/cizgili-ozel-uretim-orj-sort-sari-p-HBCV000091TB0M    0.945865
#                    ['prestijboncuk', 'trendy', 'tarlatan', 'korsed', 'series'] 434.54     5.0                      https://www.hepsiburada.com/prestijboncuk-trendy-tarlatan-korsed-series-ks-427-pm-HBC00002U8UHN    0.945641

# %%
sample_input = "Kitap"
pred_super, results = get_recommendations(
        user_text=sample_input,
        rating_class=1,
        model_type=selected_model_type,
        top_k=5
    )

print("Predicted Supercategory:", pred_super)
if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Predicted Supercategory: kitap
# Top recommended products:
#                      title  price  rating                                                                                                       product_url  similarity
#      ['sinemada', 'uslup']  224.0     5.0                                                  https://www.hepsiburada.com/sinemada-askin-uslup-pm-HB00000C4EPH    0.981124
#         ['villa', 'semer']  100.0     5.0 https://www.hepsiburada.com/villa-semer-85-necip-fazil-butun-eserleri-necip-fazil-kisakurek-pm-kbuyukdoguyay44155    0.980507
#       ['nemesis', 'nesbo']  356.8     4.7                                                       https://www.hepsiburada.com/nemesis-jo-nesbo-pm-kdogan12333    0.971258
# ['sanattan', 'yansimalar']  295.0     0.0                                                  https://www.hepsiburada.com/sanattan-yansimalar-pm-kyapiendu8212    0.970271
#      ['reklam', 'retorik']  335.0     0.0                                                     https://www.hepsiburada.com/reklam-ve-retorik-pm-HB0000012L40    0.968675

# %%
sample_input = "samsung tablet android 128gb"
pred_super, results = get_recommendations(
        user_text=sample_input,
        rating_class=1,
        model_type=selected_model_type,
        top_k=5
    )

print("Predicted Supercategory:", pred_super)
if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Predicted Supercategory: tablet
# Top recommended products:
#                                          title  price  rating                                                                                 product_url  similarity
#                ['via', 'ram', 'fhd', 'tablet'] 5999.0     4.0   https://www.hepsiburada.com/casper-via-s40-4gb-ram-128gb-10-4-fhd-tablet-pm-HBC000047GJ5Q    0.952428
# ['duvar', 'tipi', 'telefon', 'sarj', 'standi']  148.8     0.0                 https://www.hepsiburada.com/duvar-tipi-telefon-sarj-standi-pm-HBC00008B3L5I    0.943884
#           ['tablet', 'kapasite', 'ram', 'inc'] 2800.0     3.7 https://www.hepsiburada.com/vorcom-s7-tablet-32-gb-kapasite-2-gb-ram-7-inc-pm-HBC00003A9VPS    0.936467
#                              ['ips', 'tablet']    NaN     4.3                 https://www.hepsiburada.com/casper-s10-16gb-10-1-ips-tablet-p-HBV000003FTDR    0.926644
#                              ['ips', 'tablet']    NaN     3.8               https://www.hepsiburada.com/turkcell-t-16gb-8-4-5g-ips-tablet-p-HBV000006GI6R    0.926644

# %%
sample_input = "Mutfak çay makinesi"
pred_super, results = get_recommendations(
        user_text=sample_input,
        rating_class=1,
        model_type=selected_model_type,
        top_k=5
    )

print("Predicted Supercategory:", pred_super)
if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Predicted Supercategory: mutfak
# Top recommended products:
#                                 title   price  rating                                                                            product_url  similarity
#                 ['nwood', 'sandalye']  5950.0     0.0                            https://www.hepsiburada.com/nwood-sandalye-pm-HBC00009CWPAL    0.932998
#              ['bebekcocuk', 'tabure']  1475.0     0.0          https://www.hepsiburada.com/bon-chic-baby-bebek-cocuk-tabure-p-HBCV00005G7JER    0.931779
#                  ['citali', 'tabure']  2160.0     0.0                   https://www.hepsiburada.com/adm-ahsap-citali-tabure-pm-HBC00007I2YY4    0.931779
#       ['elegansia', 'masa', 'takimi'] 41990.0     0.0 https://www.hepsiburada.com/kleinhaus-furniture-elegansia-masa-takimi-p-HBCV00006EKRGL    0.928841
# ['malta', 'mutfak', 'masa', 'takimi'] 24650.0     0.0            https://www.hepsiburada.com/tekman-malta-mutfak-masa-takimi-pm-HB00000TKR8J    0.928841
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
