# %%
import pandas as pd
import numpy as np
import joblib
import tensorflow as tf
import ast
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Embedding, GRU, LSTM, Dense, Dropout, 
                                     Bidirectional, Conv1D, GlobalMaxPooling1D, 
                                     Flatten, Concatenate)
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
# Load and clean data
df = pd.read_json("../merged_cleaned_data.json")
df.dropna(subset=["title", "super_category","category_1","category_2", "Bow", "weighted_rating_class"], inplace=True)
df = df.sample(n=1000000, random_state=6).reset_index(drop=True)
# Out:
# C:\Users\kurt_\anaconda3\envs\pytorch-transformer\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
# Process labels
def list_to_str(x):
    if isinstance(x, str):
        try:
            lst = ast.literal_eval(x)
            return ' '.join(sorted(set(lst))) if isinstance(lst, list) else str(lst)
        except:
            return str(x)
    return str(x)

df["super_str"] = df["super_category"].apply(list_to_str)
df["cat1_str"] = df["category_1"].apply(list_to_str)
df["cat2_str"] = df["category_2"].apply(list_to_str)

# -------------------------------
# 2. Hiyerarşik label encoding
# -------------------------------
le_super = LabelEncoder()
df["y_super"] = le_super.fit_transform(df["super_str"])
y_super = to_categorical(df["y_super"])

# Category_1 encoding: sadece aynı supercategory içinde
cat1_mapping = {}
y_cat1_list = []
for super_label in df["super_str"].unique():
    sub_df = df[df["super_str"] == super_label]
    le = LabelEncoder()
    sub_labels = le.fit_transform(sub_df["cat1_str"])
    cat1_mapping[super_label] = le
    y_cat1_list.extend(sub_labels)
df["y_cat1"] = y_cat1_list
y_cat1 = to_categorical(df["y_cat1"])

# Category_2 encoding: sadece aynı supercategory+category_1 içinde
cat2_mapping = {}
y_cat2_list = []
for super_label in df["super_str"].unique():
    sub_df1 = df[df["super_str"] == super_label]
    cat2_mapping[super_label] = {}
    for cat1_label in sub_df1["cat1_str"].unique():
        sub_df2 = sub_df1[sub_df1["cat1_str"] == cat1_label]
        le = LabelEncoder()
        sub_labels = le.fit_transform(sub_df2["cat2_str"])
        cat2_mapping[super_label][cat1_label] = le
        y_cat2_list.extend(sub_labels)
df["y_cat2"] = y_cat2_list
y_cat2 = to_categorical(df["y_cat2"])

# %%
# -------------------------------
# 3. Metin temizleme ve tokenization
# -------------------------------
def clean_text(text):
    if isinstance(text, str):
        words = text.lower().strip().split()
        return ' '.join(sorted(set(words)))
    return ""

df["clean_text"] = df["Bow"].apply(clean_text)
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(df["clean_text"])
seq = tokenizer.texts_to_sequences(df["clean_text"])
padded_seq = pad_sequences(seq, maxlen=40, padding="post")

# -------------------------------
# 4. Train-test split
# -------------------------------
X_train_text, X_test_text, y_train_super, y_test_super, y_train_cat1, y_test_cat1, y_train_cat2, y_test_cat2 = train_test_split(
    padded_seq, y_super, y_cat1, y_cat2, test_size=0.3, random_state=42, stratify=np.argmax(y_super, axis=1)
)

# %%
# -------------------------------
# 5. Model mimarisi
# -------------------------------
def build_model(model_type="bigru"):
    input_text = Input(shape=(40,))
    x = Embedding(input_dim=5000, output_dim=300)(input_text)
    
    if model_type == "gru":
        x = GRU(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3)(x)
        x = GRU(128, dropout=0.3, recurrent_dropout=0.3)(x)
    elif model_type == "lstm":
        x = LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3)(x)
        x = LSTM(128, dropout=0.3, recurrent_dropout=0.3)(x)
    elif model_type == "bigru":
        x = Bidirectional(GRU(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))(x)
        x = GlobalMaxPooling1D()(x)
    elif model_type == "bilstm":
        x = Bidirectional(LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))(x)
        x = GlobalMaxPooling1D()(x)
    elif model_type == "cnn":
        x = Conv1D(128, 5, activation='relu')(x)
        x = GlobalMaxPooling1D()(x)
    elif model_type == "mlp":
        x = Flatten()(x)
    else:
        raise ValueError("Invalid model type")

    z = Dropout(0.5)(x)
    z = Dense(256, activation='relu')(z)

    output_super = Dense(y_super.shape[1], activation='softmax', name="super_output")(z)
    output_cat1 = Dense(y_cat1.shape[1], activation='softmax', name="cat1_output")(z)
    output_cat2 = Dense(y_cat2.shape[1], activation='softmax', name="cat2_output")(z)

    model = Model(inputs=input_text, outputs=[output_super, output_cat1, output_cat2])
    model.compile(optimizer=Adam(0.00025),
                  loss="categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# %%
# -------------------------------
# 6. Eğitim fonksiyonu
# -------------------------------
def train(model_type="bigru"):
    model = build_model(model_type)
    history = model.fit(
        X_train_text,
        [y_train_super, y_train_cat1, y_train_cat2],
        validation_data=(X_test_text, [y_test_super, y_test_cat1, y_test_cat2]),
        epochs=5,
        batch_size=32,
        callbacks=[EarlyStopping(patience=3, restore_best_weights=True)]
    )
    model.save(f"{model_type}_multioutput_model.keras")
    joblib.dump(tokenizer, "tokenizer.pkl")
    joblib.dump(le_super, "le_super.pkl")
    joblib.dump(cat1_mapping, "cat1_mapping.pkl")
    joblib.dump(cat2_mapping, "cat2_mapping.pkl")
    return history

# %%
# -------------------------------
# 7. Hiyerarşik öneri fonksiyonu
# -------------------------------
def get_recommendations(user_text, model_type="bigru", top_k=5):
    model = tf.keras.models.load_model(f"{model_type}_multioutput_model.keras")
    tokenizer = joblib.load("tokenizer.pkl")
    le_super = joblib.load("le_super.pkl")
    cat1_mapping = joblib.load("cat1_mapping.pkl")
    cat2_mapping = joblib.load("cat2_mapping.pkl")

    clean_input = ' '.join(sorted(set(user_text.lower().strip().split())))
    seq = tokenizer.texts_to_sequences([clean_input])
    padded = pad_sequences(seq, maxlen=40, padding="post")

    preds_super, preds_cat1, preds_cat2 = model.predict(padded, verbose=0)
    pred_super_idx = np.argmax(preds_super)
    pred_super = le_super.inverse_transform([pred_super_idx])[0]

    # Category_1 hiyerarşik seçim
    le_cat1 = cat1_mapping[pred_super]
    pred_cat1_idx = np.argmax(preds_cat1)
    pred_cat1 = le_cat1.inverse_transform([pred_cat1_idx])[0]

    # Category_2 hiyerarşik seçim
    le_cat2 = cat2_mapping[pred_super][pred_cat1]
    pred_cat2_idx = np.argmax(preds_cat2)
    pred_cat2 = le_cat2.inverse_transform([pred_cat2_idx])[0]

    # Hiyerarşik filtreleme
    filtered_df = df[
        (df["super_str"] == pred_super) &
        (df["cat1_str"] == pred_cat1) &
        (df["cat2_str"] == pred_cat2)
    ].copy()
    if len(filtered_df) == 0:
        return (pred_super, pred_cat1, pred_cat2), None

    # Embedding tabanlı öneri
    embed_model = Model(inputs=model.inputs, outputs=model.layers[-3].output)
    user_embedding = embed_model.predict(padded, verbose=0)
    seqs = tokenizer.texts_to_sequences(filtered_df["clean_text"])
    padded_seqs = pad_sequences(seqs, maxlen=40, padding="post")
    prod_embeddings = embed_model.predict(padded_seqs, verbose=0)

    similarities = cosine_similarity(user_embedding, prod_embeddings)[0]
    filtered_df["similarity"] = similarities
    top_products = filtered_df.sort_values(by="similarity", ascending=False).head(top_k)

    return (pred_super, pred_cat1, pred_cat2), top_products[["title", "price", "rating", "product_url", "similarity"]]

# %%
# -------------------------------
# 8. Örnek kullanım
# -------------------------------
selected_model_type = "cnn"
train(selected_model_type)

sample_input = "Araç torpido üstü aksesuarı"
(pred_super, pred_cat1, pred_cat2), results = get_recommendations(
    user_text=sample_input,
    model_type=selected_model_type,
    top_k=5
)

print("Predicted Supercategory:", pred_super)
print("Predicted Category_1:", pred_cat1)
print("Predicted Category_2:", pred_cat2)

if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# Epoch 1/5
# 21875/21875 [==============================] - 120s 5ms/step - loss: 4.2013 - super_output_loss: 0.0290 - cat1_output_loss: 1.6842 - cat2_output_loss: 2.4881 - super_output_accuracy: 0.9933 - cat1_output_accuracy: 0.3762 - cat2_output_accuracy: 0.1723 - val_loss: 4.1479 - val_super_output_loss: 8.7325e-05 - val_cat1_output_loss: 1.6715 - val_cat2_output_loss: 2.4763 - val_super_output_accuracy: 1.0000 - val_cat1_output_accuracy: 0.3803 - val_cat2_output_accuracy: 0.1757
# Epoch 2/5
# 21875/21875 [==============================] - 119s 5ms/step - loss: 4.1497 - super_output_loss: 0.0019 - cat1_output_loss: 1.6728 - cat2_output_loss: 2.4750 - super_output_accuracy: 0.9997 - cat1_output_accuracy: 0.3796 - cat2_output_accuracy: 0.1754 - val_loss: 4.1462 - val_super_output_loss: 8.1864e-05 - val_cat1_output_loss: 1.6706 - val_cat2_output_loss: 2.4755 - val_super_output_accuracy: 1.0000 - val_cat1_output_accuracy: 0.3803 - val_cat2_output_accuracy: 0.1764
# Epoch 3/5
# 21875/21875 [==============================] - 116s 5ms/step - loss: 4.1455 - super_output_loss: 0.0016 - cat1_output_loss: 1.6711 - cat2_output_loss: 2.4728 - super_output_accuracy: 0.9997 - cat1_output_accuracy: 0.3798 - cat2_output_accuracy: 0.1775 - val_loss: 4.1488 - val_super_output_loss: 1.1292e-04 - val_cat1_output_loss: 1.6713 - val_cat2_output_loss: 2.4774 - val_super_output_accuracy: 1.0000 - val_cat1_output_accuracy: 0.3803 - val_cat2_output_accuracy: 0.1751
# Epoch 4/5
# 21875/21875 [==============================] - 124s 6ms/step - loss: 4.1413 - super_output_loss: 0.0017 - cat1_output_loss: 1.6692 - cat2_output_loss: 2.4704 - super_output_accuracy: 0.9996 - cat1_output_accuracy: 0.3798 - cat2_output_accuracy: 0.1789 - val_loss: 4.1532 - val_super_output_loss: 1.4754e-04 - val_cat1_output_loss: 1.6750 - val_cat2_output_loss: 2.4780 - val_super_output_accuracy: 1.0000 - val_cat1_output_accuracy: 0.3803 - val_cat2_output_accuracy: 0.1739
# Epoch 5/5
# 21875/21875 [==============================] - 119s 5ms/step - loss: 4.1354 - super_output_loss: 0.0018 - cat1_output_loss: 1.6664 - cat2_output_loss: 2.4670 - super_output_accuracy: 0.9995 - cat1_output_accuracy: 0.3798 - cat2_output_accuracy: 0.1814 - val_loss: 4.1583 - val_super_output_loss: 1.5778e-04 - val_cat1_output_loss: 1.6774 - val_cat2_output_loss: 2.4807 - val_super_output_accuracy: 1.0000 - val_cat1_output_accuracy: 0.3802 - val_cat2_output_accuracy: 0.1766
# Predicted Supercategory: moda
# Predicted Category_1: giyim ayakkabi
# Predicted Category_2: erkek
# Top recommended products:
#                                                                                                                             title   price  rating                                                                                                                                                                                    product_url  similarity
#                                                                          ince yasam tummy wrap bel inceltici lastik inceltici jel  599.00     0.0                                                                                       https://www.hepsiburada.com/ince-yasam-tummy-wrap-bel-inceltici-lastik-ve-inceltici-jel-pm-HBC000035WCNA    0.972896
#                               sik pratik modern yasam icin ideal cozum kullanisli yapimi hakiki deri kredi kartlik moon kah rengi  699.00     5.0                https://www.hepsiburada.com/cach-e-concept-sik-ve-pratik-modern-yasam-icin-ideal-cozum-hafif-ve-kullanisli-el-yapimi-hakiki-deri-kredi-kartlik-moon-kahverengi-p-HBCV00000JS1SX    0.958172
#                                                                                          umre market hac umre icin erkek sandalet  750.00     0.0                                                                                              https://www.hepsiburada.com/rolezyum-umre-market-hac-ve-umre-icin-erkek-sandalet-p-HBCV00006UOEVH    0.943611
# erkekler kadinlar icin kosu kemeri gecirmez neopren spor kemeri yansitici ayarlanabilir cep telefonu tutucu turuncu yurt disindan 2575.60     0.0 https://www.hepsiburada.com/bisbisous-erkekler-ve-kadinlar-icin-kosu-kemeri-su-gecirmez-neopren-spor-kemeri-yansitici-ayarlanabilir-cep-telefonu-tutucu-turuncu-yurt-disindan-pm-HBC00007D8WVB    0.942830
#                                                                                     eagle erkek siyah outdoor erkek spor ayakkabi 1812.48     4.0                                                                                           https://www.hepsiburada.com/lumberjack-eagle-erkek-siyah-outdoor-erkek-spor-ayakkabi-p-HBV00000U43HP    0.942411

# %%
sample_input = "Kadın kot pantolon lacivert"
(pred_super, pred_cat1, pred_cat2), results = get_recommendations(
    user_text=sample_input,
    model_type=selected_model_type,
    top_k=5
)

print("Predicted Supercategory:", pred_super)
print("Predicted Category_1:", pred_cat1)
print("Predicted Category_2:", pred_cat2)

if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# Predicted Supercategory: moda
# Predicted Category_1: giyim ayakkabi
# Predicted Category_2: erkek
# Top recommended products:
#                                                                                                                                                   title   price  rating                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    product_url  similarity
#                                                                                                ince yasam tummy wrap bel inceltici lastik inceltici jel  599.00     0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       https://www.hepsiburada.com/ince-yasam-tummy-wrap-bel-inceltici-lastik-ve-inceltici-jel-pm-HBC000035WCNA    0.979253
#                                                     sik pratik modern yasam icin ideal cozum kullanisli yapimi hakiki deri kredi kartlik moon kah rengi  699.00     5.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                https://www.hepsiburada.com/cach-e-concept-sik-ve-pratik-modern-yasam-icin-ideal-cozum-hafif-ve-kullanisli-el-yapimi-hakiki-deri-kredi-kartlik-moon-kahverengi-p-HBCV00000JS1SX    0.969359
#                                                                                                                umre market hac umre icin erkek sandalet  750.00     0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              https://www.hepsiburada.com/rolezyum-umre-market-hac-ve-umre-icin-erkek-sandalet-p-HBCV00006UOEVH    0.957639
#                       erkekler kadinlar icin kosu kemeri gecirmez neopren spor kemeri yansitici ayarlanabilir cep telefonu tutucu turuncu yurt disindan 2575.60     0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 https://www.hepsiburada.com/bisbisous-erkekler-ve-kadinlar-icin-kosu-kemeri-su-gecirmez-neopren-spor-kemeri-yansitici-ayarlanabilir-cep-telefonu-tutucu-turuncu-yurt-disindan-pm-HBC00007D8WVB    0.956750
# iscilik luks hakiki gercek deri siyah renk seffaf gozlu ehliyetlik kimlik gozlu slim super ince mini deri kartvizitlik kucuk kartlik deri kredi kartlik 1495.02     5.0 https://adservice.hepsiburada.com/event/api/v1/track?event=...&redirect=https%3A%2F%2Fwww.hepsiburada.com%2Fmimodish-012-1-sinif-iscilik-luks-hakiki-gercek-deri-siyah-renk-seffaf-gozlu-ehliyetlik-kimlik-gozlu-slim-super-ince-mini-deri-kartvizitlik-kucuk-kartlik-deri-kredi-kartlik-p-HBCV000070LYQG%3Fmagaza%3DMimodish&eventName=sp-click&platform=desktop    0.956378

# %%
sample_input = "Araç içi aksesuarı ışıklandırma seti"
(pred_super, pred_cat1, pred_cat2), results = get_recommendations(
    user_text=sample_input,
    model_type=selected_model_type,
    top_k=5
)

print("Predicted Supercategory:", pred_super)
print("Predicted Category_1:", pred_cat1)
print("Predicted Category_2:", pred_cat2)

if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# Predicted Supercategory: moda
# Predicted Category_1: giyim ayakkabi
# Predicted Category_2: erkek
# Top recommended products:
#                                                                                                                             title   price  rating                                                                                                                                                                                    product_url  similarity
#                                                                          ince yasam tummy wrap bel inceltici lastik inceltici jel  599.00     0.0                                                                                       https://www.hepsiburada.com/ince-yasam-tummy-wrap-bel-inceltici-lastik-ve-inceltici-jel-pm-HBC000035WCNA    0.964585
#                               sik pratik modern yasam icin ideal cozum kullanisli yapimi hakiki deri kredi kartlik moon kah rengi  699.00     5.0                https://www.hepsiburada.com/cach-e-concept-sik-ve-pratik-modern-yasam-icin-ideal-cozum-hafif-ve-kullanisli-el-yapimi-hakiki-deri-kredi-kartlik-moon-kahverengi-p-HBCV00000JS1SX    0.945337
#                                                                                          umre market hac umre icin erkek sandalet  750.00     0.0                                                                                              https://www.hepsiburada.com/rolezyum-umre-market-hac-ve-umre-icin-erkek-sandalet-p-HBCV00006UOEVH    0.927987
# erkekler kadinlar icin kosu kemeri gecirmez neopren spor kemeri yansitici ayarlanabilir cep telefonu tutucu turuncu yurt disindan 2575.60     0.0 https://www.hepsiburada.com/bisbisous-erkekler-ve-kadinlar-icin-kosu-kemeri-su-gecirmez-neopren-spor-kemeri-yansitici-ayarlanabilir-cep-telefonu-tutucu-turuncu-yurt-disindan-pm-HBC00007D8WVB    0.927269
#                                                                                     eagle erkek siyah outdoor erkek spor ayakkabi 1812.48     4.0                                                                                           https://www.hepsiburada.com/lumberjack-eagle-erkek-siyah-outdoor-erkek-spor-ayakkabi-p-HBV00000U43HP    0.926976

# %%
sample_input = "Iphone cep telefonu aksesuarı telefon tutacağı"
(pred_super, pred_cat1, pred_cat2), results = get_recommendations(
    user_text=sample_input,
    model_type=selected_model_type,
    top_k=5
)

print("Predicted Supercategory:", pred_super)
print("Predicted Category_1:", pred_cat1)
print("Predicted Category_2:", pred_cat2)

if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# Predicted Supercategory: elektronik
# Predicted Category_1: elektronigi
# Predicted Category_2: isitma sogutma
# Top recommended products:
#                                                                                               title  price  rating                                                                                                                                                         product_url  similarity
#                                        mini klima portatif tasinabilir sogutucu led isikli ofis oto 1259.9     1.8                                       https://www.hepsiburada.com/herkesetoptantic-mini-klima-portatif-tasinabilir-sogutucu-led-isikli-ev-ofis-oto-pm-HBC000010L2GL    0.999995
# masaustu mini isitici ofis masaustu anne bebek hizli isitma kucuk tasinabilir isitici yurt disindan 2220.4     0.0  https://www.hepsiburada.com/khalid-bain-masaustu-mini-isitici-ev-ofis-masaustu-anne-ve-bebek-hizli-isitma-kucuk-tasinabilir-isitici-yurt-disindan-p-HBCV00007AYISV    0.999994
# masaustu mini isitici ofis masaustu anne bebek hizli isitma kucuk tasinabilir isitici yurt disindan 2230.0     0.0 https://www.hepsiburada.com/synchrolssue-masaustu-mini-isitici-ev-ofis-masaustu-anne-ve-bebek-hizli-isitma-kucuk-tasinabilir-isitici-yurt-disindan-p-HBCV00007ETQJT    0.999994
#                                                           kaskar taflan firelli watt panel kon ktor 4999.9     4.0                                                                 https://www.hepsiburada.com/firelli-kaskar-taflan-firelli-1500-watt-panel-konvektor-pm-HB00001B5SSW    0.999994
# masaustu mini isitici ofis masaustu anne bebek hizli isitma kucuk tasinabilir isitici yurt disindan 2230.4     0.0      https://www.hepsiburada.com/servisi-masaustu-mini-isitici-ev-ofis-masaustu-anne-ve-bebek-hizli-isitma-kucuk-tasinabilir-isitici-yurt-disindan-p-HBCV00007B8MSL    0.999994

# %%
sample_input = "Nvidia 3060 ekran kartlı notebook bilgisayar lenovo"
(pred_super, pred_cat1, pred_cat2), results = get_recommendations(
    user_text=sample_input,
    model_type=selected_model_type,
    top_k=5
)

print("Predicted Supercategory:", pred_super)
print("Predicted Category_1:", pred_cat1)
print("Predicted Category_2:", pred_cat2)

if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# Predicted Supercategory: elektronik
# Predicted Category_1: elektronigi
# Predicted Category_2: isitma sogutma
# Top recommended products:
#                                                                                                                         title  price  rating                                                                                                                                                                                       product_url  similarity
#                                                                  mini klima portatif tasinabilir sogutucu led isikli ofis oto 1259.9     1.8                                                                     https://www.hepsiburada.com/herkesetoptantic-mini-klima-portatif-tasinabilir-sogutucu-led-isikli-ev-ofis-oto-pm-HBC000010L2GL    0.939977
#                                                                                     halojen soba infrared termostatli isitici 2800.0     2.0                                                                                                      https://www.hepsiburada.com/halojen-soba-infrared-termostatli-isitici-1800w-pm-HBC00007E33IN    0.939951
# isitici kucuk isitma ofis masaustu yurt sicak enerji tasarrufu saglayan kucuk gunes enerjili elektrikli isitici yurt disindan 1765.2     0.0 https://www.hepsiburada.com/synchrolssue-isitici-ev-kucuk-sessiz-isitma-ofis-masaustu-yurt-sicak-enerji-tasarrufu-saglayan-kucuk-gunes-enerjili-elektrikli-isitici-yurt-disindan-p-HBCV00007ETQJF    0.939945
# isitici kucuk isitma ofis masaustu yurt sicak enerji tasarrufu saglayan kucuk gunes enerjili elektrikli isitici yurt disindan 1765.2     0.0    https://www.hepsiburada.com/intragdou-isitici-ev-kucuk-sessiz-isitma-ofis-masaustu-yurt-sicak-enerji-tasarrufu-saglayan-kucuk-gunes-enerjili-elektrikli-isitici-yurt-disindan-p-HBCV00007ES9OF    0.939945
# isitici kucuk isitma ofis masaustu yurt sicak enerji tasarrufu saglayan kucuk gunes enerjili elektrikli isitici yurt disindan 1765.2     0.0       https://www.hepsiburada.com/xavier-isitici-ev-kucuk-sessiz-isitma-ofis-masaustu-yurt-sicak-enerji-tasarrufu-saglayan-kucuk-gunes-enerjili-elektrikli-isitici-yurt-disindan-p-HBCV00007B9MI8    0.939945

# %%
sample_input = "Erkek alt giyim pantolon"
(pred_super, pred_cat1, pred_cat2), results = get_recommendations(
    user_text=sample_input,
    model_type=selected_model_type,
    top_k=5
)

print("Predicted Supercategory:", pred_super)
print("Predicted Category_1:", pred_cat1)
print("Predicted Category_2:", pred_cat2)

if results is not None:
    print("Top recommended products:")
    print(results.to_string(index=False))
else:
    print("No products found in this supercategory")
# Out:
# Predicted Supercategory: moda
# Predicted Category_1: giyim ayakkabi
# Predicted Category_2: erkek
# Top recommended products:
#                                                                                                                                                   title   price  rating                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    product_url  similarity
#                                                                                                ince yasam tummy wrap bel inceltici lastik inceltici jel  599.00     0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       https://www.hepsiburada.com/ince-yasam-tummy-wrap-bel-inceltici-lastik-ve-inceltici-jel-pm-HBC000035WCNA    0.982124
#                                                     sik pratik modern yasam icin ideal cozum kullanisli yapimi hakiki deri kredi kartlik moon kah rengi  699.00     5.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                https://www.hepsiburada.com/cach-e-concept-sik-ve-pratik-modern-yasam-icin-ideal-cozum-hafif-ve-kullanisli-el-yapimi-hakiki-deri-kredi-kartlik-moon-kahverengi-p-HBCV00000JS1SX    0.969190
#                                                                                                                umre market hac umre icin erkek sandalet  750.00     0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              https://www.hepsiburada.com/rolezyum-umre-market-hac-ve-umre-icin-erkek-sandalet-p-HBCV00006UOEVH    0.954632
#                       erkekler kadinlar icin kosu kemeri gecirmez neopren spor kemeri yansitici ayarlanabilir cep telefonu tutucu turuncu yurt disindan 2575.60     0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 https://www.hepsiburada.com/bisbisous-erkekler-ve-kadinlar-icin-kosu-kemeri-su-gecirmez-neopren-spor-kemeri-yansitici-ayarlanabilir-cep-telefonu-tutucu-turuncu-yurt-disindan-pm-HBC00007D8WVB    0.954374
# iscilik luks hakiki gercek deri siyah renk seffaf gozlu ehliyetlik kimlik gozlu slim super ince mini deri kartvizitlik kucuk kartlik deri kredi kartlik 1495.02     5.0 https://adservice.hepsiburada.com/event/api/v1/track?event=...&redirect=https%3A%2F%2Fwww.hepsiburada.com%2Fmimodish-012-1-sinif-iscilik-luks-hakiki-gercek-deri-siyah-renk-seffaf-gozlu-ehliyetlik-kimlik-gozlu-slim-super-ince-mini-deri-kartvizitlik-kucuk-kartlik-deri-kredi-kartlik-p-HBCV000070LYQG%3Fmagaza%3DMimodish&eventName=sp-click&platform=desktop    0.954255
